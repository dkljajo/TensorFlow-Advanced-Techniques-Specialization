# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 941us/sample - loss: 227.3091 - y1_output_loss: 110.8595 - y2_output_loss: 114.6412 - y1_output_root_mean_squared_error: 10.5735 - y2_output_root_mean_squared_error: 10.7476 - val_loss: 43.0128 - val_y1_output_loss: 14.1805 - val_y2_output_loss: 28.7652 - val_y1_output_root_mean_squared_error: 3.7865 - val_y2_output_root_mean_squared_error: 5.3549
# Epoch 2/500
# 614/614 [==============================] - 0s 143us/sample - loss: 37.0208 - y1_output_loss: 13.3072 - y2_output_loss: 23.4842 - y1_output_root_mean_squared_error: 3.6615 - y2_output_root_mean_squared_error: 4.8594 - val_loss: 20.9930 - val_y1_output_loss: 8.6063 - val_y2_output_loss: 12.1232 - val_y1_output_root_mean_squared_error: 2.9658 - val_y2_output_root_mean_squared_error: 3.4924
# Epoch 3/500
# 614/614 [==============================] - 0s 141us/sample - loss: 25.8120 - y1_output_loss: 10.2401 - y2_output_loss: 15.4575 - y1_output_root_mean_squared_error: 3.2105 - y2_output_root_mean_squared_error: 3.9376 - val_loss: 18.1248 - val_y1_output_loss: 7.5257 - val_y2_output_loss: 10.2728 - val_y1_output_root_mean_squared_error: 2.7795 - val_y2_output_root_mean_squared_error: 3.2248
# Epoch 4/500
# 614/614 [==============================] - 0s 141us/sample - loss: 26.6771 - y1_output_loss: 9.9336 - y2_output_loss: 17.2018 - y1_output_root_mean_squared_error: 3.1281 - y2_output_root_mean_squared_error: 4.1100 - val_loss: 102.9018 - val_y1_output_loss: 23.0612 - val_y2_output_loss: 78.4405 - val_y1_output_root_mean_squared_error: 4.8617 - val_y2_output_root_mean_squared_error: 8.9031
# Epoch 5/500
# 614/614 [==============================] - 0s 139us/sample - loss: 26.5817 - y1_output_loss: 10.2527 - y2_output_loss: 16.5453 - y1_output_root_mean_squared_error: 3.2016 - y2_output_root_mean_squared_error: 4.0412 - val_loss: 30.9196 - val_y1_output_loss: 8.3425 - val_y2_output_loss: 22.0653 - val_y1_output_root_mean_squared_error: 2.9315 - val_y2_output_root_mean_squared_error: 4.7250
# Epoch 6/500
# 614/614 [==============================] - 0s 139us/sample - loss: 27.2098 - y1_output_loss: 9.8536 - y2_output_loss: 17.3432 - y1_output_root_mean_squared_error: 3.1459 - y2_output_root_mean_squared_error: 4.1609 - val_loss: 31.2376 - val_y1_output_loss: 9.0266 - val_y2_output_loss: 21.1870 - val_y1_output_root_mean_squared_error: 3.0551 - val_y2_output_root_mean_squared_error: 4.6802
# Epoch 7/500
# 614/614 [==============================] - 0s 136us/sample - loss: 22.5791 - y1_output_loss: 9.1121 - y2_output_loss: 13.3003 - y1_output_root_mean_squared_error: 3.0311 - y2_output_root_mean_squared_error: 3.6594 - val_loss: 15.4132 - val_y1_output_loss: 6.7271 - val_y2_output_loss: 8.2470 - val_y1_output_root_mean_squared_error: 2.6339 - val_y2_output_root_mean_squared_error: 2.9113
# Epoch 8/500
# 614/614 [==============================] - 0s 136us/sample - loss: 21.9952 - y1_output_loss: 8.6482 - y2_output_loss: 13.1891 - y1_output_root_mean_squared_error: 2.9474 - y2_output_root_mean_squared_error: 3.6480 - val_loss: 22.7389 - val_y1_output_loss: 10.6863 - val_y2_output_loss: 11.7106 - val_y1_output_root_mean_squared_error: 3.3036 - val_y2_output_root_mean_squared_error: 3.4387
# Epoch 9/500
# 614/614 [==============================] - 0s 136us/sample - loss: 22.9932 - y1_output_loss: 8.8818 - y2_output_loss: 14.0566 - y1_output_root_mean_squared_error: 2.9865 - y2_output_root_mean_squared_error: 3.7515 - val_loss: 16.0687 - val_y1_output_loss: 6.9963 - val_y2_output_loss: 8.8034 - val_y1_output_root_mean_squared_error: 2.6755 - val_y2_output_root_mean_squared_error: 2.9851
# Epoch 10/500
# 614/614 [==============================] - 0s 140us/sample - loss: 22.3795 - y1_output_loss: 8.4325 - y2_output_loss: 13.8893 - y1_output_root_mean_squared_error: 2.9142 - y2_output_root_mean_squared_error: 3.7265 - val_loss: 19.2654 - val_y1_output_loss: 6.9956 - val_y2_output_loss: 11.9404 - val_y1_output_root_mean_squared_error: 2.6833 - val_y2_output_root_mean_squared_error: 3.4735
# Epoch 11/500
# 614/614 [==============================] - 0s 137us/sample - loss: 22.0912 - y1_output_loss: 8.5297 - y2_output_loss: 13.5484 - y1_output_root_mean_squared_error: 2.9119 - y2_output_root_mean_squared_error: 3.6895 - val_loss: 16.9546 - val_y1_output_loss: 6.7915 - val_y2_output_loss: 9.7387 - val_y1_output_root_mean_squared_error: 2.6466 - val_y2_output_root_mean_squared_error: 3.1544
# Epoch 12/500
# 614/614 [==============================] - 0s 139us/sample - loss: 25.0489 - y1_output_loss: 8.7686 - y2_output_loss: 16.0763 - y1_output_root_mean_squared_error: 2.9706 - y2_output_root_mean_squared_error: 4.0279 - val_loss: 13.5511 - val_y1_output_loss: 5.4670 - val_y2_output_loss: 7.6527 - val_y1_output_root_mean_squared_error: 2.3762 - val_y2_output_root_mean_squared_error: 2.8115
# Epoch 13/500
# 614/614 [==============================] - 0s 136us/sample - loss: 21.1126 - y1_output_loss: 8.1441 - y2_output_loss: 12.8009 - y1_output_root_mean_squared_error: 2.8637 - y2_output_root_mean_squared_error: 3.5933 - val_loss: 14.8307 - val_y1_output_loss: 6.2847 - val_y2_output_loss: 8.2671 - val_y1_output_root_mean_squared_error: 2.5409 - val_y2_output_root_mean_squared_error: 2.8939
# Epoch 14/500
# 614/614 [==============================] - 0s 135us/sample - loss: 18.5504 - y1_output_loss: 7.4625 - y2_output_loss: 10.9452 - y1_output_root_mean_squared_error: 2.7425 - y2_output_root_mean_squared_error: 3.3210 - val_loss: 11.8504 - val_y1_output_loss: 5.1502 - val_y2_output_loss: 6.4106 - val_y1_output_root_mean_squared_error: 2.3026 - val_y2_output_root_mean_squared_error: 2.5590
# Epoch 15/500
# 614/614 [==============================] - 0s 133us/sample - loss: 19.5167 - y1_output_loss: 7.3465 - y2_output_loss: 12.1559 - y1_output_root_mean_squared_error: 2.7140 - y2_output_root_mean_squared_error: 3.4858 - val_loss: 12.6144 - val_y1_output_loss: 5.4251 - val_y2_output_loss: 6.8930 - val_y1_output_root_mean_squared_error: 2.3605 - val_y2_output_root_mean_squared_error: 2.6538
# Epoch 16/500
# 614/614 [==============================] - 0s 134us/sample - loss: 19.8296 - y1_output_loss: 7.4574 - y2_output_loss: 12.2551 - y1_output_root_mean_squared_error: 2.7417 - y2_output_root_mean_squared_error: 3.5089 - val_loss: 13.0092 - val_y1_output_loss: 5.9057 - val_y2_output_loss: 6.9717 - val_y1_output_root_mean_squared_error: 2.4554 - val_y2_output_root_mean_squared_error: 2.6420
# Epoch 17/500
# 614/614 [==============================] - 0s 132us/sample - loss: 16.0516 - y1_output_loss: 6.4424 - y2_output_loss: 9.6352 - y1_output_root_mean_squared_error: 2.5362 - y2_output_root_mean_squared_error: 3.1015 - val_loss: 11.6145 - val_y1_output_loss: 5.0107 - val_y2_output_loss: 6.4814 - val_y1_output_root_mean_squared_error: 2.2622 - val_y2_output_root_mean_squared_error: 2.5489
# Epoch 18/500
# 614/614 [==============================] - 0s 133us/sample - loss: 17.3041 - y1_output_loss: 6.8528 - y2_output_loss: 10.4092 - y1_output_root_mean_squared_error: 2.6262 - y2_output_root_mean_squared_error: 3.2260 - val_loss: 16.7689 - val_y1_output_loss: 5.7036 - val_y2_output_loss: 10.4948 - val_y1_output_root_mean_squared_error: 2.4282 - val_y2_output_root_mean_squared_error: 3.2974
# Epoch 19/500
# 614/614 [==============================] - 0s 133us/sample - loss: 17.5689 - y1_output_loss: 6.3240 - y2_output_loss: 11.1039 - y1_output_root_mean_squared_error: 2.5254 - y2_output_root_mean_squared_error: 3.3454 - val_loss: 10.3686 - val_y1_output_loss: 4.6997 - val_y2_output_loss: 5.5349 - val_y1_output_root_mean_squared_error: 2.1899 - val_y2_output_root_mean_squared_error: 2.3607
# Epoch 20/500
# 614/614 [==============================] - 0s 131us/sample - loss: 17.5065 - y1_output_loss: 6.4367 - y2_output_loss: 10.9338 - y1_output_root_mean_squared_error: 2.5457 - y2_output_root_mean_squared_error: 3.3205 - val_loss: 12.9164 - val_y1_output_loss: 6.1496 - val_y2_output_loss: 6.7334 - val_y1_output_root_mean_squared_error: 2.4972 - val_y2_output_root_mean_squared_error: 2.5847
# Epoch 21/500
# 614/614 [==============================] - 0s 131us/sample - loss: 14.6748 - y1_output_loss: 5.6541 - y2_output_loss: 8.9448 - y1_output_root_mean_squared_error: 2.3861 - y2_output_root_mean_squared_error: 2.9969 - val_loss: 9.7984 - val_y1_output_loss: 4.3808 - val_y2_output_loss: 5.2907 - val_y1_output_root_mean_squared_error: 2.1140 - val_y2_output_root_mean_squared_error: 2.3085
# Epoch 22/500
# 614/614 [==============================] - 0s 132us/sample - loss: 13.9677 - y1_output_loss: 5.2821 - y2_output_loss: 8.7620 - y1_output_root_mean_squared_error: 2.2905 - y2_output_root_mean_squared_error: 2.9532 - val_loss: 36.5261 - val_y1_output_loss: 9.6683 - val_y2_output_loss: 25.6917 - val_y1_output_root_mean_squared_error: 3.1596 - val_y2_output_root_mean_squared_error: 5.1520
# Epoch 23/500
# 614/614 [==============================] - 0s 135us/sample - loss: 14.0863 - y1_output_loss: 5.1644 - y2_output_loss: 8.7898 - y1_output_root_mean_squared_error: 2.2834 - y2_output_root_mean_squared_error: 2.9787 - val_loss: 9.1931 - val_y1_output_loss: 4.2857 - val_y2_output_loss: 4.8199 - val_y1_output_root_mean_squared_error: 2.0930 - val_y2_output_root_mean_squared_error: 2.1937
# Epoch 24/500
# 614/614 [==============================] - 0s 131us/sample - loss: 14.9113 - y1_output_loss: 5.5297 - y2_output_loss: 9.4585 - y1_output_root_mean_squared_error: 2.3361 - y2_output_root_mean_squared_error: 3.0747 - val_loss: 19.9998 - val_y1_output_loss: 8.6730 - val_y2_output_loss: 10.9717 - val_y1_output_root_mean_squared_error: 2.9851 - val_y2_output_root_mean_squared_error: 3.3300
# Epoch 25/500
# 614/614 [==============================] - 0s 132us/sample - loss: 13.8318 - y1_output_loss: 5.1852 - y2_output_loss: 8.6908 - y1_output_root_mean_squared_error: 2.2727 - y2_output_root_mean_squared_error: 2.9439 - val_loss: 18.0810 - val_y1_output_loss: 6.2562 - val_y2_output_loss: 11.8883 - val_y1_output_root_mean_squared_error: 2.5170 - val_y2_output_root_mean_squared_error: 3.4272
# Epoch 26/500
# 614/614 [==============================] - 0s 131us/sample - loss: 16.3239 - y1_output_loss: 5.3825 - y2_output_loss: 10.9021 - y1_output_root_mean_squared_error: 2.3176 - y2_output_root_mean_squared_error: 3.3094 - val_loss: 15.9091 - val_y1_output_loss: 6.2384 - val_y2_output_loss: 9.6608 - val_y1_output_root_mean_squared_error: 2.5208 - val_y2_output_root_mean_squared_error: 3.0910
# Epoch 27/500
# 614/614 [==============================] - 0s 131us/sample - loss: 12.3040 - y1_output_loss: 4.6282 - y2_output_loss: 7.8518 - y1_output_root_mean_squared_error: 2.1322 - y2_output_root_mean_squared_error: 2.7852 - val_loss: 10.3303 - val_y1_output_loss: 3.8324 - val_y2_output_loss: 6.1956 - val_y1_output_root_mean_squared_error: 1.9892 - val_y2_output_root_mean_squared_error: 2.5246
# Epoch 28/500
# 614/614 [==============================] - 0s 131us/sample - loss: 13.8014 - y1_output_loss: 4.7675 - y2_output_loss: 8.9226 - y1_output_root_mean_squared_error: 2.1937 - y2_output_root_mean_squared_error: 2.9982 - val_loss: 7.2897 - val_y1_output_loss: 3.2631 - val_y2_output_loss: 3.9750 - val_y1_output_root_mean_squared_error: 1.8267 - val_y2_output_root_mean_squared_error: 1.9882
# Epoch 29/500
# 614/614 [==============================] - 0s 131us/sample - loss: 10.0365 - y1_output_loss: 3.8242 - y2_output_loss: 6.2015 - y1_output_root_mean_squared_error: 1.9465 - y2_output_root_mean_squared_error: 2.4995 - val_loss: 11.3218 - val_y1_output_loss: 4.8607 - val_y2_output_loss: 6.1345 - val_y1_output_root_mean_squared_error: 2.2430 - val_y2_output_root_mean_squared_error: 2.5082
# Epoch 30/500
# 614/614 [==============================] - 0s 132us/sample - loss: 12.1377 - y1_output_loss: 4.4665 - y2_output_loss: 7.6215 - y1_output_root_mean_squared_error: 2.1107 - y2_output_root_mean_squared_error: 2.7717 - val_loss: 8.0499 - val_y1_output_loss: 3.9214 - val_y2_output_loss: 3.9700 - val_y1_output_root_mean_squared_error: 2.0121 - val_y2_output_root_mean_squared_error: 2.0003
# Epoch 31/500
# 614/614 [==============================] - 0s 140us/sample - loss: 10.3213 - y1_output_loss: 3.6851 - y2_output_loss: 6.5637 - y1_output_root_mean_squared_error: 1.9278 - y2_output_root_mean_squared_error: 2.5700 - val_loss: 8.2715 - val_y1_output_loss: 3.0552 - val_y2_output_loss: 5.2652 - val_y1_output_root_mean_squared_error: 1.7681 - val_y2_output_root_mean_squared_error: 2.2684
# Epoch 32/500
# 614/614 [==============================] - 0s 139us/sample - loss: 11.3950 - y1_output_loss: 3.7654 - y2_output_loss: 7.5629 - y1_output_root_mean_squared_error: 1.9424 - y2_output_root_mean_squared_error: 2.7608 - val_loss: 7.1304 - val_y1_output_loss: 3.1024 - val_y2_output_loss: 4.0197 - val_y1_output_root_mean_squared_error: 1.7908 - val_y2_output_root_mean_squared_error: 1.9808
# Epoch 33/500
# 614/614 [==============================] - 0s 141us/sample - loss: 9.2168 - y1_output_loss: 3.5178 - y2_output_loss: 5.6915 - y1_output_root_mean_squared_error: 1.8680 - y2_output_root_mean_squared_error: 2.3932 - val_loss: 8.6446 - val_y1_output_loss: 3.6696 - val_y2_output_loss: 5.0668 - val_y1_output_root_mean_squared_error: 1.9327 - val_y2_output_root_mean_squared_error: 2.2157
# Epoch 34/500
# 614/614 [==============================] - 0s 147us/sample - loss: 10.2095 - y1_output_loss: 3.3568 - y2_output_loss: 6.7722 - y1_output_root_mean_squared_error: 1.8391 - y2_output_root_mean_squared_error: 2.6129 - val_loss: 7.2567 - val_y1_output_loss: 3.0221 - val_y2_output_loss: 4.1811 - val_y1_output_root_mean_squared_error: 1.7639 - val_y2_output_root_mean_squared_error: 2.0360
# Epoch 35/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.9575 - y1_output_loss: 3.2673 - y2_output_loss: 6.7799 - y1_output_root_mean_squared_error: 1.7896 - y2_output_root_mean_squared_error: 2.5990 - val_loss: 16.1640 - val_y1_output_loss: 5.9358 - val_y2_output_loss: 9.6632 - val_y1_output_root_mean_squared_error: 2.4817 - val_y2_output_root_mean_squared_error: 3.1631
# Epoch 36/500
# 614/614 [==============================] - 0s 131us/sample - loss: 9.1431 - y1_output_loss: 3.0489 - y2_output_loss: 6.0868 - y1_output_root_mean_squared_error: 1.7472 - y2_output_root_mean_squared_error: 2.4678 - val_loss: 11.6967 - val_y1_output_loss: 4.2033 - val_y2_output_loss: 7.6077 - val_y1_output_root_mean_squared_error: 2.0638 - val_y2_output_root_mean_squared_error: 2.7272
# Epoch 37/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.1199 - y1_output_loss: 2.7853 - y2_output_loss: 5.3734 - y1_output_root_mean_squared_error: 1.6730 - y2_output_root_mean_squared_error: 2.3067 - val_loss: 22.3631 - val_y1_output_loss: 5.2480 - val_y2_output_loss: 16.3227 - val_y1_output_root_mean_squared_error: 2.3340 - val_y2_output_root_mean_squared_error: 4.1128
# Epoch 38/500
# 614/614 [==============================] - 0s 133us/sample - loss: 9.9586 - y1_output_loss: 3.2701 - y2_output_loss: 6.6857 - y1_output_root_mean_squared_error: 1.8122 - y2_output_root_mean_squared_error: 2.5835 - val_loss: 8.9902 - val_y1_output_loss: 3.0935 - val_y2_output_loss: 5.6015 - val_y1_output_root_mean_squared_error: 1.7896 - val_y2_output_root_mean_squared_error: 2.4058
# Epoch 39/500
# 614/614 [==============================] - 0s 142us/sample - loss: 10.2605 - y1_output_loss: 2.9968 - y2_output_loss: 7.2398 - y1_output_root_mean_squared_error: 1.7272 - y2_output_root_mean_squared_error: 2.6976 - val_loss: 7.4053 - val_y1_output_loss: 3.0926 - val_y2_output_loss: 4.3437 - val_y1_output_root_mean_squared_error: 1.7753 - val_y2_output_root_mean_squared_error: 2.0625
# Epoch 40/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.3543 - y1_output_loss: 2.6922 - y2_output_loss: 5.6412 - y1_output_root_mean_squared_error: 1.6401 - y2_output_root_mean_squared_error: 2.3800 - val_loss: 13.9702 - val_y1_output_loss: 4.3610 - val_y2_output_loss: 9.5492 - val_y1_output_root_mean_squared_error: 2.1118 - val_y2_output_root_mean_squared_error: 3.0839
# Epoch 41/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.0329 - y1_output_loss: 2.7225 - y2_output_loss: 6.3234 - y1_output_root_mean_squared_error: 1.6497 - y2_output_root_mean_squared_error: 2.5122 - val_loss: 7.8030 - val_y1_output_loss: 2.9059 - val_y2_output_loss: 4.6665 - val_y1_output_root_mean_squared_error: 1.7333 - val_y2_output_root_mean_squared_error: 2.1906
# Epoch 42/500
# 614/614 [==============================] - 0s 143us/sample - loss: 9.2732 - y1_output_loss: 2.8844 - y2_output_loss: 6.3946 - y1_output_root_mean_squared_error: 1.7020 - y2_output_root_mean_squared_error: 2.5252 - val_loss: 12.3361 - val_y1_output_loss: 2.7928 - val_y2_output_loss: 9.1280 - val_y1_output_root_mean_squared_error: 1.7005 - val_y2_output_root_mean_squared_error: 3.0732
# Epoch 43/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.9018 - y1_output_loss: 2.3981 - y2_output_loss: 5.4643 - y1_output_root_mean_squared_error: 1.5557 - y2_output_root_mean_squared_error: 2.3413 - val_loss: 5.5010 - val_y1_output_loss: 2.2489 - val_y2_output_loss: 3.2748 - val_y1_output_root_mean_squared_error: 1.5200 - val_y2_output_root_mean_squared_error: 1.7862
# Epoch 44/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.8009 - y1_output_loss: 2.1549 - y2_output_loss: 4.6725 - y1_output_root_mean_squared_error: 1.4608 - y2_output_root_mean_squared_error: 2.1603 - val_loss: 13.8422 - val_y1_output_loss: 5.3739 - val_y2_output_loss: 8.5244 - val_y1_output_root_mean_squared_error: 2.3348 - val_y2_output_root_mean_squared_error: 2.8967
# Epoch 45/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.7930 - y1_output_loss: 2.2651 - y2_output_loss: 5.5949 - y1_output_root_mean_squared_error: 1.5048 - y2_output_root_mean_squared_error: 2.3513 - val_loss: 5.4003 - val_y1_output_loss: 2.1098 - val_y2_output_loss: 3.1498 - val_y1_output_root_mean_squared_error: 1.4774 - val_y2_output_root_mean_squared_error: 1.7938
# Epoch 46/500
# 614/614 [==============================] - 0s 135us/sample - loss: 8.9670 - y1_output_loss: 2.6481 - y2_output_loss: 6.2813 - y1_output_root_mean_squared_error: 1.6235 - y2_output_root_mean_squared_error: 2.5162 - val_loss: 7.6962 - val_y1_output_loss: 3.1093 - val_y2_output_loss: 4.6268 - val_y1_output_root_mean_squared_error: 1.7796 - val_y2_output_root_mean_squared_error: 2.1282
# Epoch 47/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.7960 - y1_output_loss: 2.2118 - y2_output_loss: 4.5371 - y1_output_root_mean_squared_error: 1.4898 - y2_output_root_mean_squared_error: 2.1393 - val_loss: 5.3831 - val_y1_output_loss: 2.5446 - val_y2_output_loss: 2.8590 - val_y1_output_root_mean_squared_error: 1.6116 - val_y2_output_root_mean_squared_error: 1.6691
# Epoch 48/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.3934 - y1_output_loss: 2.1945 - y2_output_loss: 5.2826 - y1_output_root_mean_squared_error: 1.4764 - y2_output_root_mean_squared_error: 2.2834 - val_loss: 6.4602 - val_y1_output_loss: 1.9308 - val_y2_output_loss: 4.3158 - val_y1_output_root_mean_squared_error: 1.4153 - val_y2_output_root_mean_squared_error: 2.1112
# Epoch 49/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.9243 - y1_output_loss: 2.2126 - y2_output_loss: 5.6912 - y1_output_root_mean_squared_error: 1.4841 - y2_output_root_mean_squared_error: 2.3920 - val_loss: 5.3187 - val_y1_output_loss: 2.2095 - val_y2_output_loss: 2.9532 - val_y1_output_root_mean_squared_error: 1.5127 - val_y2_output_root_mean_squared_error: 1.7409
# Epoch 50/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.7686 - y1_output_loss: 1.8227 - y2_output_loss: 4.9030 - y1_output_root_mean_squared_error: 1.3511 - y2_output_root_mean_squared_error: 2.2233 - val_loss: 4.3642 - val_y1_output_loss: 1.8610 - val_y2_output_loss: 2.4293 - val_y1_output_root_mean_squared_error: 1.3895 - val_y2_output_root_mean_squared_error: 1.5600
# Epoch 51/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.7709 - y1_output_loss: 2.2531 - y2_output_loss: 4.4861 - y1_output_root_mean_squared_error: 1.5019 - y2_output_root_mean_squared_error: 2.1249 - val_loss: 4.2588 - val_y1_output_loss: 1.7934 - val_y2_output_loss: 2.3836 - val_y1_output_root_mean_squared_error: 1.3648 - val_y2_output_root_mean_squared_error: 1.5480
# Epoch 52/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.8967 - y1_output_loss: 1.6890 - y2_output_loss: 4.1759 - y1_output_root_mean_squared_error: 1.3003 - y2_output_root_mean_squared_error: 2.0508 - val_loss: 5.3878 - val_y1_output_loss: 2.1590 - val_y2_output_loss: 3.2446 - val_y1_output_root_mean_squared_error: 1.4885 - val_y2_output_root_mean_squared_error: 1.7811
# Epoch 53/500
# 614/614 [==============================] - 0s 138us/sample - loss: 5.5638 - y1_output_loss: 1.6775 - y2_output_loss: 3.8460 - y1_output_root_mean_squared_error: 1.2988 - y2_output_root_mean_squared_error: 1.9690 - val_loss: 8.9647 - val_y1_output_loss: 3.5502 - val_y2_output_loss: 5.1352 - val_y1_output_root_mean_squared_error: 1.9182 - val_y2_output_root_mean_squared_error: 2.2990
# Epoch 54/500
# 614/614 [==============================] - 0s 135us/sample - loss: 8.2824 - y1_output_loss: 2.2430 - y2_output_loss: 6.2668 - y1_output_root_mean_squared_error: 1.5043 - y2_output_root_mean_squared_error: 2.4535 - val_loss: 37.7406 - val_y1_output_loss: 5.4877 - val_y2_output_loss: 31.0665 - val_y1_output_root_mean_squared_error: 2.3846 - val_y2_output_root_mean_squared_error: 5.6616
# Epoch 55/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.1423 - y1_output_loss: 2.0411 - y2_output_loss: 6.0578 - y1_output_root_mean_squared_error: 1.4321 - y2_output_root_mean_squared_error: 2.4681 - val_loss: 4.2508 - val_y1_output_loss: 1.7492 - val_y2_output_loss: 2.3939 - val_y1_output_root_mean_squared_error: 1.3467 - val_y2_output_root_mean_squared_error: 1.5611
# Epoch 56/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.6796 - y1_output_loss: 1.6923 - y2_output_loss: 4.9694 - y1_output_root_mean_squared_error: 1.3057 - y2_output_root_mean_squared_error: 2.2304 - val_loss: 5.5616 - val_y1_output_loss: 2.3404 - val_y2_output_loss: 3.1681 - val_y1_output_root_mean_squared_error: 1.5523 - val_y2_output_root_mean_squared_error: 1.7753
# Epoch 57/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.8857 - y1_output_loss: 1.9765 - y2_output_loss: 4.8780 - y1_output_root_mean_squared_error: 1.4034 - y2_output_root_mean_squared_error: 2.2173 - val_loss: 13.4358 - val_y1_output_loss: 4.9209 - val_y2_output_loss: 8.3769 - val_y1_output_root_mean_squared_error: 2.2472 - val_y2_output_root_mean_squared_error: 2.8959
# Epoch 58/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.8557 - y1_output_loss: 2.2052 - y2_output_loss: 5.6369 - y1_output_root_mean_squared_error: 1.4896 - y2_output_root_mean_squared_error: 2.3742 - val_loss: 7.3660 - val_y1_output_loss: 2.0516 - val_y2_output_loss: 5.0468 - val_y1_output_root_mean_squared_error: 1.4588 - val_y2_output_root_mean_squared_error: 2.2887
# Epoch 59/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.0637 - y1_output_loss: 1.9038 - y2_output_loss: 5.1059 - y1_output_root_mean_squared_error: 1.3833 - y2_output_root_mean_squared_error: 2.2694 - val_loss: 4.0123 - val_y1_output_loss: 1.6251 - val_y2_output_loss: 2.3028 - val_y1_output_root_mean_squared_error: 1.2977 - val_y2_output_root_mean_squared_error: 1.5259
# Epoch 60/500
# 614/614 [==============================] - 0s 133us/sample - loss: 10.0321 - y1_output_loss: 2.8340 - y2_output_loss: 7.1524 - y1_output_root_mean_squared_error: 1.6816 - y2_output_root_mean_squared_error: 2.6841 - val_loss: 3.8057 - val_y1_output_loss: 1.5258 - val_y2_output_loss: 2.2134 - val_y1_output_root_mean_squared_error: 1.2536 - val_y2_output_root_mean_squared_error: 1.4947
# Epoch 61/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.8701 - y1_output_loss: 1.3985 - y2_output_loss: 3.4368 - y1_output_root_mean_squared_error: 1.1869 - y2_output_root_mean_squared_error: 1.8605 - val_loss: 3.4275 - val_y1_output_loss: 1.5067 - val_y2_output_loss: 1.8883 - val_y1_output_root_mean_squared_error: 1.2463 - val_y2_output_root_mean_squared_error: 1.3690
# Epoch 62/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.6892 - y1_output_loss: 2.0071 - y2_output_loss: 5.9019 - y1_output_root_mean_squared_error: 1.4223 - y2_output_root_mean_squared_error: 2.3804 - val_loss: 36.4784 - val_y1_output_loss: 6.0080 - val_y2_output_loss: 29.5077 - val_y1_output_root_mean_squared_error: 2.4862 - val_y2_output_root_mean_squared_error: 5.5043
# Epoch 63/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.1469 - y1_output_loss: 1.4112 - y2_output_loss: 3.7091 - y1_output_root_mean_squared_error: 1.1844 - y2_output_root_mean_squared_error: 1.9350 - val_loss: 3.9012 - val_y1_output_loss: 2.0069 - val_y2_output_loss: 1.8380 - val_y1_output_root_mean_squared_error: 1.4351 - val_y2_output_root_mean_squared_error: 1.3571
# Epoch 64/500
# 614/614 [==============================] - 0s 138us/sample - loss: 8.1592 - y1_output_loss: 2.3735 - y2_output_loss: 5.7616 - y1_output_root_mean_squared_error: 1.5452 - y2_output_root_mean_squared_error: 2.4024 - val_loss: 6.5723 - val_y1_output_loss: 1.2331 - val_y2_output_loss: 5.1125 - val_y1_output_root_mean_squared_error: 1.1318 - val_y2_output_root_mean_squared_error: 2.3003
# Epoch 65/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.1787 - y1_output_loss: 1.6120 - y2_output_loss: 4.5639 - y1_output_root_mean_squared_error: 1.2719 - y2_output_root_mean_squared_error: 2.1357 - val_loss: 4.6858 - val_y1_output_loss: 1.9494 - val_y2_output_loss: 2.6585 - val_y1_output_root_mean_squared_error: 1.4216 - val_y2_output_root_mean_squared_error: 1.6324
# Epoch 66/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.0500 - y1_output_loss: 1.6000 - y2_output_loss: 4.4150 - y1_output_root_mean_squared_error: 1.2636 - y2_output_root_mean_squared_error: 2.1103 - val_loss: 5.1998 - val_y1_output_loss: 2.3655 - val_y2_output_loss: 2.7605 - val_y1_output_root_mean_squared_error: 1.5616 - val_y2_output_root_mean_squared_error: 1.6617
# Epoch 67/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.2719 - y1_output_loss: 1.1147 - y2_output_loss: 3.1272 - y1_output_root_mean_squared_error: 1.0590 - y2_output_root_mean_squared_error: 1.7749 - val_loss: 6.6897 - val_y1_output_loss: 1.6370 - val_y2_output_loss: 4.8133 - val_y1_output_root_mean_squared_error: 1.3010 - val_y2_output_root_mean_squared_error: 2.2354
# Epoch 68/500
# 614/614 [==============================] - 0s 141us/sample - loss: 7.3762 - y1_output_loss: 2.5833 - y2_output_loss: 4.7232 - y1_output_root_mean_squared_error: 1.6149 - y2_output_root_mean_squared_error: 2.1836 - val_loss: 2.8290 - val_y1_output_loss: 0.9081 - val_y2_output_loss: 1.8424 - val_y1_output_root_mean_squared_error: 0.9698 - val_y2_output_root_mean_squared_error: 1.3742
# Epoch 69/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.9453 - y1_output_loss: 1.1544 - y2_output_loss: 2.7908 - y1_output_root_mean_squared_error: 1.0760 - y2_output_root_mean_squared_error: 1.6696 - val_loss: 7.5250 - val_y1_output_loss: 1.6722 - val_y2_output_loss: 5.5943 - val_y1_output_root_mean_squared_error: 1.3141 - val_y2_output_root_mean_squared_error: 2.4079
# Epoch 70/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.8767 - y1_output_loss: 1.5092 - y2_output_loss: 3.7948 - y1_output_root_mean_squared_error: 1.1441 - y2_output_root_mean_squared_error: 1.8888 - val_loss: 135.6677 - val_y1_output_loss: 53.4145 - val_y2_output_loss: 78.2233 - val_y1_output_root_mean_squared_error: 7.4370 - val_y2_output_root_mean_squared_error: 8.9643
# Epoch 71/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.9954 - y1_output_loss: 2.6679 - y2_output_loss: 6.2887 - y1_output_root_mean_squared_error: 1.6379 - y2_output_root_mean_squared_error: 2.5125 - val_loss: 10.1108 - val_y1_output_loss: 2.8686 - val_y2_output_loss: 7.1273 - val_y1_output_root_mean_squared_error: 1.7193 - val_y2_output_root_mean_squared_error: 2.6748
# Epoch 72/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.3971 - y1_output_loss: 1.1562 - y2_output_loss: 3.4083 - y1_output_root_mean_squared_error: 1.0381 - y2_output_root_mean_squared_error: 1.8219 - val_loss: 31.7489 - val_y1_output_loss: 10.5831 - val_y2_output_loss: 20.4406 - val_y1_output_root_mean_squared_error: 3.3070 - val_y2_output_root_mean_squared_error: 4.5621
# Epoch 73/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.6187 - y1_output_loss: 1.6359 - y2_output_loss: 4.0502 - y1_output_root_mean_squared_error: 1.2694 - y2_output_root_mean_squared_error: 2.0018 - val_loss: 8.0439 - val_y1_output_loss: 4.1317 - val_y2_output_loss: 3.6579 - val_y1_output_root_mean_squared_error: 2.0698 - val_y2_output_root_mean_squared_error: 1.9390
# Epoch 74/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.2747 - y1_output_loss: 0.9803 - y2_output_loss: 2.2833 - y1_output_root_mean_squared_error: 0.9916 - y2_output_root_mean_squared_error: 1.5137 - val_loss: 2.8379 - val_y1_output_loss: 0.9087 - val_y2_output_loss: 1.8419 - val_y1_output_root_mean_squared_error: 0.9688 - val_y2_output_root_mean_squared_error: 1.3782
# Epoch 75/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.0493 - y1_output_loss: 0.9778 - y2_output_loss: 3.0795 - y1_output_root_mean_squared_error: 0.9891 - y2_output_root_mean_squared_error: 1.7524 - val_loss: 3.6521 - val_y1_output_loss: 0.8534 - val_y2_output_loss: 2.6728 - val_y1_output_root_mean_squared_error: 0.9374 - val_y2_output_root_mean_squared_error: 1.6654
# Epoch 76/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.9289 - y1_output_loss: 1.7734 - y2_output_loss: 4.3891 - y1_output_root_mean_squared_error: 1.2862 - y2_output_root_mean_squared_error: 2.0675 - val_loss: 31.7854 - val_y1_output_loss: 11.7873 - val_y2_output_loss: 18.8799 - val_y1_output_root_mean_squared_error: 3.4945 - val_y2_output_root_mean_squared_error: 4.4242
# Epoch 77/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.5290 - y1_output_loss: 1.6658 - y2_output_loss: 4.8195 - y1_output_root_mean_squared_error: 1.2951 - y2_output_root_mean_squared_error: 2.2027 - val_loss: 3.1196 - val_y1_output_loss: 1.0380 - val_y2_output_loss: 2.0449 - val_y1_output_root_mean_squared_error: 1.0362 - val_y2_output_root_mean_squared_error: 1.4303
# Epoch 78/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.6053 - y1_output_loss: 1.1113 - y2_output_loss: 3.4772 - y1_output_root_mean_squared_error: 1.0587 - y2_output_root_mean_squared_error: 1.8666 - val_loss: 5.8800 - val_y1_output_loss: 1.3818 - val_y2_output_loss: 4.2885 - val_y1_output_root_mean_squared_error: 1.1955 - val_y2_output_root_mean_squared_error: 2.1097
# Epoch 79/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.6023 - y1_output_loss: 1.5214 - y2_output_loss: 4.0566 - y1_output_root_mean_squared_error: 1.2339 - y2_output_root_mean_squared_error: 2.0199 - val_loss: 5.3601 - val_y1_output_loss: 1.3666 - val_y2_output_loss: 3.9441 - val_y1_output_root_mean_squared_error: 1.1881 - val_y2_output_root_mean_squared_error: 1.9871
# Epoch 80/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.1146 - y1_output_loss: 1.4336 - y2_output_loss: 3.6446 - y1_output_root_mean_squared_error: 1.2005 - y2_output_root_mean_squared_error: 1.9166 - val_loss: 3.2476 - val_y1_output_loss: 1.0364 - val_y2_output_loss: 2.1044 - val_y1_output_root_mean_squared_error: 1.0354 - val_y2_output_root_mean_squared_error: 1.4749
# Epoch 81/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.2112 - y1_output_loss: 0.7398 - y2_output_loss: 2.4740 - y1_output_root_mean_squared_error: 0.8631 - y2_output_root_mean_squared_error: 1.5704 - val_loss: 3.3129 - val_y1_output_loss: 1.0359 - val_y2_output_loss: 2.2389 - val_y1_output_root_mean_squared_error: 1.0341 - val_y2_output_root_mean_squared_error: 1.4979
# Epoch 82/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.5068 - y1_output_loss: 0.8351 - y2_output_loss: 2.6572 - y1_output_root_mean_squared_error: 0.9177 - y2_output_root_mean_squared_error: 1.6324 - val_loss: 2.5906 - val_y1_output_loss: 0.8472 - val_y2_output_loss: 1.6875 - val_y1_output_root_mean_squared_error: 0.9327 - val_y2_output_root_mean_squared_error: 1.3117
# Epoch 83/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.9064 - y1_output_loss: 0.9469 - y2_output_loss: 2.9462 - y1_output_root_mean_squared_error: 0.9722 - y2_output_root_mean_squared_error: 1.7208 - val_loss: 2.0718 - val_y1_output_loss: 0.6861 - val_y2_output_loss: 1.3445 - val_y1_output_root_mean_squared_error: 0.8399 - val_y2_output_root_mean_squared_error: 1.1689
# Epoch 84/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.8093 - y1_output_loss: 0.6496 - y2_output_loss: 2.1456 - y1_output_root_mean_squared_error: 0.8058 - y2_output_root_mean_squared_error: 1.4697 - val_loss: 2.6462 - val_y1_output_loss: 0.9350 - val_y2_output_loss: 1.6716 - val_y1_output_root_mean_squared_error: 0.9844 - val_y2_output_root_mean_squared_error: 1.2951
# Epoch 85/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.7346 - y1_output_loss: 1.0101 - y2_output_loss: 3.7436 - y1_output_root_mean_squared_error: 1.0030 - y2_output_root_mean_squared_error: 1.9310 - val_loss: 4.6483 - val_y1_output_loss: 0.7737 - val_y2_output_loss: 3.7127 - val_y1_output_root_mean_squared_error: 0.8918 - val_y2_output_root_mean_squared_error: 1.9629
# Epoch 86/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.5571 - y1_output_loss: 0.9640 - y2_output_loss: 2.5799 - y1_output_root_mean_squared_error: 0.9772 - y2_output_root_mean_squared_error: 1.6131 - val_loss: 5.5609 - val_y1_output_loss: 2.4672 - val_y2_output_loss: 2.9966 - val_y1_output_root_mean_squared_error: 1.5954 - val_y2_output_root_mean_squared_error: 1.7366
# Epoch 87/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.4628 - y1_output_loss: 0.8197 - y2_output_loss: 2.6598 - y1_output_root_mean_squared_error: 0.9064 - y2_output_root_mean_squared_error: 1.6252 - val_loss: 3.5625 - val_y1_output_loss: 0.9521 - val_y2_output_loss: 2.5933 - val_y1_output_root_mean_squared_error: 0.9859 - val_y2_output_root_mean_squared_error: 1.6095
# Epoch 88/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.3803 - y1_output_loss: 0.7322 - y2_output_loss: 2.6390 - y1_output_root_mean_squared_error: 0.8550 - y2_output_root_mean_squared_error: 1.6277 - val_loss: 2.7264 - val_y1_output_loss: 1.0532 - val_y2_output_loss: 1.6172 - val_y1_output_root_mean_squared_error: 1.0436 - val_y2_output_root_mean_squared_error: 1.2795
# Epoch 89/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.4554 - y1_output_loss: 0.8491 - y2_output_loss: 2.7043 - y1_output_root_mean_squared_error: 0.8871 - y2_output_root_mean_squared_error: 1.6335 - val_loss: 55.3988 - val_y1_output_loss: 18.5185 - val_y2_output_loss: 34.9598 - val_y1_output_root_mean_squared_error: 4.3804 - val_y2_output_root_mean_squared_error: 6.0176
# Epoch 90/500
# 614/614 [==============================] - 0s 138us/sample - loss: 14.5959 - y1_output_loss: 5.0350 - y2_output_loss: 9.4379 - y1_output_root_mean_squared_error: 2.2524 - y2_output_root_mean_squared_error: 3.0859 - val_loss: 3.1588 - val_y1_output_loss: 1.1138 - val_y2_output_loss: 1.9722 - val_y1_output_root_mean_squared_error: 1.0740 - val_y2_output_root_mean_squared_error: 1.4161
# Epoch 91/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.4867 - y1_output_loss: 0.7866 - y2_output_loss: 2.6884 - y1_output_root_mean_squared_error: 0.8871 - y2_output_root_mean_squared_error: 1.6431 - val_loss: 2.8652 - val_y1_output_loss: 0.7616 - val_y2_output_loss: 2.0080 - val_y1_output_root_mean_squared_error: 0.8888 - val_y2_output_root_mean_squared_error: 1.4406
# Epoch 92/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.6023 - y1_output_loss: 0.6017 - y2_output_loss: 1.9848 - y1_output_root_mean_squared_error: 0.7748 - y2_output_root_mean_squared_error: 1.4149 - val_loss: 2.1427 - val_y1_output_loss: 0.7251 - val_y2_output_loss: 1.3695 - val_y1_output_root_mean_squared_error: 0.8639 - val_y2_output_root_mean_squared_error: 1.1817
# Epoch 93/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.1855 - y1_output_loss: 0.7997 - y2_output_loss: 2.3682 - y1_output_root_mean_squared_error: 0.8960 - y2_output_root_mean_squared_error: 1.5436 - val_loss: 7.0615 - val_y1_output_loss: 2.6857 - val_y2_output_loss: 4.2104 - val_y1_output_root_mean_squared_error: 1.6681 - val_y2_output_root_mean_squared_error: 2.0685
# Epoch 94/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.4655 - y1_output_loss: 0.7548 - y2_output_loss: 2.6974 - y1_output_root_mean_squared_error: 0.8681 - y2_output_root_mean_squared_error: 1.6468 - val_loss: 2.0614 - val_y1_output_loss: 0.7591 - val_y2_output_loss: 1.2724 - val_y1_output_root_mean_squared_error: 0.8851 - val_y2_output_root_mean_squared_error: 1.1305
# Epoch 95/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.3889 - y1_output_loss: 0.8795 - y2_output_loss: 2.4902 - y1_output_root_mean_squared_error: 0.9371 - y2_output_root_mean_squared_error: 1.5845 - val_loss: 2.1242 - val_y1_output_loss: 0.7735 - val_y2_output_loss: 1.2999 - val_y1_output_root_mean_squared_error: 0.8955 - val_y2_output_root_mean_squared_error: 1.1500
# Epoch 96/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.9342 - y1_output_loss: 0.6576 - y2_output_loss: 2.3403 - y1_output_root_mean_squared_error: 0.8131 - y2_output_root_mean_squared_error: 1.5077 - val_loss: 6.8077 - val_y1_output_loss: 1.0981 - val_y2_output_loss: 5.6820 - val_y1_output_root_mean_squared_error: 1.0643 - val_y2_output_root_mean_squared_error: 2.3822
# Epoch 97/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.1624 - y1_output_loss: 0.7368 - y2_output_loss: 2.4393 - y1_output_root_mean_squared_error: 0.8611 - y2_output_root_mean_squared_error: 1.5559 - val_loss: 2.3536 - val_y1_output_loss: 0.8203 - val_y2_output_loss: 1.4640 - val_y1_output_root_mean_squared_error: 0.9185 - val_y2_output_root_mean_squared_error: 1.2288
# Epoch 98/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.3997 - y1_output_loss: 0.8656 - y2_output_loss: 2.5480 - y1_output_root_mean_squared_error: 0.9314 - y2_output_root_mean_squared_error: 1.5913 - val_loss: 4.4904 - val_y1_output_loss: 0.9838 - val_y2_output_loss: 3.5513 - val_y1_output_root_mean_squared_error: 1.0058 - val_y2_output_root_mean_squared_error: 1.8651
# Epoch 99/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.7694 - y1_output_loss: 0.6237 - y2_output_loss: 2.1713 - y1_output_root_mean_squared_error: 0.7845 - y2_output_root_mean_squared_error: 1.4676 - val_loss: 4.7145 - val_y1_output_loss: 2.3728 - val_y2_output_loss: 2.2094 - val_y1_output_root_mean_squared_error: 1.5695 - val_y2_output_root_mean_squared_error: 1.5004
# Epoch 100/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.4420 - y1_output_loss: 0.5899 - y2_output_loss: 1.8618 - y1_output_root_mean_squared_error: 0.7691 - y2_output_root_mean_squared_error: 1.3603 - val_loss: 5.9285 - val_y1_output_loss: 1.2458 - val_y2_output_loss: 4.6577 - val_y1_output_root_mean_squared_error: 1.1335 - val_y2_output_root_mean_squared_error: 2.1549
# Epoch 101/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.4877 - y1_output_loss: 0.8693 - y2_output_loss: 2.6080 - y1_output_root_mean_squared_error: 0.9328 - y2_output_root_mean_squared_error: 1.6179 - val_loss: 3.5811 - val_y1_output_loss: 1.4609 - val_y2_output_loss: 2.0779 - val_y1_output_root_mean_squared_error: 1.2193 - val_y2_output_root_mean_squared_error: 1.4472
# Epoch 102/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.8414 - y1_output_loss: 0.6082 - y2_output_loss: 2.2270 - y1_output_root_mean_squared_error: 0.7810 - y2_output_root_mean_squared_error: 1.4938 - val_loss: 4.9825 - val_y1_output_loss: 1.8360 - val_y2_output_loss: 3.0214 - val_y1_output_root_mean_squared_error: 1.3672 - val_y2_output_root_mean_squared_error: 1.7645
# Epoch 103/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.0508 - y1_output_loss: 0.5964 - y2_output_loss: 2.4459 - y1_output_root_mean_squared_error: 0.7741 - y2_output_root_mean_squared_error: 1.5657 - val_loss: 3.8890 - val_y1_output_loss: 1.5587 - val_y2_output_loss: 2.2440 - val_y1_output_root_mean_squared_error: 1.2687 - val_y2_output_root_mean_squared_error: 1.5097
# Epoch 104/500
# 614/614 [==============================] - 0s 137us/sample - loss: 7.0528 - y1_output_loss: 1.9129 - y2_output_loss: 5.0856 - y1_output_root_mean_squared_error: 1.3864 - y2_output_root_mean_squared_error: 2.2651 - val_loss: 2.7773 - val_y1_output_loss: 0.9034 - val_y2_output_loss: 1.8687 - val_y1_output_root_mean_squared_error: 0.9610 - val_y2_output_root_mean_squared_error: 1.3615
# Epoch 105/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.8744 - y1_output_loss: 0.7051 - y2_output_loss: 2.1495 - y1_output_root_mean_squared_error: 0.8424 - y2_output_root_mean_squared_error: 1.4713 - val_loss: 2.4066 - val_y1_output_loss: 0.7592 - val_y2_output_loss: 1.6392 - val_y1_output_root_mean_squared_error: 0.8833 - val_y2_output_root_mean_squared_error: 1.2753
# Epoch 106/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.3770 - y1_output_loss: 0.7634 - y2_output_loss: 2.6036 - y1_output_root_mean_squared_error: 0.8728 - y2_output_root_mean_squared_error: 1.6172 - val_loss: 1.7510 - val_y1_output_loss: 0.5570 - val_y2_output_loss: 1.1613 - val_y1_output_root_mean_squared_error: 0.7567 - val_y2_output_root_mean_squared_error: 1.0855
# Epoch 107/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.2446 - y1_output_loss: 0.5298 - y2_output_loss: 1.7046 - y1_output_root_mean_squared_error: 0.7294 - y2_output_root_mean_squared_error: 1.3086 - val_loss: 1.8341 - val_y1_output_loss: 0.7137 - val_y2_output_loss: 1.0865 - val_y1_output_root_mean_squared_error: 0.8601 - val_y2_output_root_mean_squared_error: 1.0461
# Epoch 108/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.1407 - y1_output_loss: 0.5071 - y2_output_loss: 1.7030 - y1_output_root_mean_squared_error: 0.7040 - y2_output_root_mean_squared_error: 1.2826 - val_loss: 7.5119 - val_y1_output_loss: 1.6442 - val_y2_output_loss: 5.6053 - val_y1_output_root_mean_squared_error: 1.3053 - val_y2_output_root_mean_squared_error: 2.4100
# Epoch 109/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.5980 - y1_output_loss: 0.6337 - y2_output_loss: 1.9452 - y1_output_root_mean_squared_error: 0.7977 - y2_output_root_mean_squared_error: 1.4006 - val_loss: 1.8477 - val_y1_output_loss: 0.6646 - val_y2_output_loss: 1.1582 - val_y1_output_root_mean_squared_error: 0.8250 - val_y2_output_root_mean_squared_error: 1.0803
# Epoch 110/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.3751 - y1_output_loss: 1.3097 - y2_output_loss: 3.0325 - y1_output_root_mean_squared_error: 1.1465 - y2_output_root_mean_squared_error: 1.7494 - val_loss: 2.1222 - val_y1_output_loss: 0.6434 - val_y2_output_loss: 1.4446 - val_y1_output_root_mean_squared_error: 0.8163 - val_y2_output_root_mean_squared_error: 1.2066
# Epoch 111/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.1619 - y1_output_loss: 0.8035 - y2_output_loss: 2.3547 - y1_output_root_mean_squared_error: 0.8983 - y2_output_root_mean_squared_error: 1.5346 - val_loss: 5.0532 - val_y1_output_loss: 1.0814 - val_y2_output_loss: 3.8151 - val_y1_output_root_mean_squared_error: 1.0484 - val_y2_output_root_mean_squared_error: 1.9885
# Epoch 112/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.3573 - y1_output_loss: 0.5283 - y2_output_loss: 1.8357 - y1_output_root_mean_squared_error: 0.7286 - y2_output_root_mean_squared_error: 1.3515 - val_loss: 1.7397 - val_y1_output_loss: 0.5582 - val_y2_output_loss: 1.1497 - val_y1_output_root_mean_squared_error: 0.7606 - val_y2_output_root_mean_squared_error: 1.0776
# Epoch 113/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.5410 - y1_output_loss: 0.5232 - y2_output_loss: 2.0289 - y1_output_root_mean_squared_error: 0.7170 - y2_output_root_mean_squared_error: 1.4237 - val_loss: 2.3210 - val_y1_output_loss: 0.7349 - val_y2_output_loss: 1.5692 - val_y1_output_root_mean_squared_error: 0.8702 - val_y2_output_root_mean_squared_error: 1.2505
# Epoch 114/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.4097 - y1_output_loss: 0.5324 - y2_output_loss: 1.8905 - y1_output_root_mean_squared_error: 0.7327 - y2_output_root_mean_squared_error: 1.3685 - val_loss: 4.9287 - val_y1_output_loss: 0.6125 - val_y2_output_loss: 4.2855 - val_y1_output_root_mean_squared_error: 0.7966 - val_y2_output_root_mean_squared_error: 2.0723
# Epoch 115/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.1812 - y1_output_loss: 0.7544 - y2_output_loss: 2.5465 - y1_output_root_mean_squared_error: 0.8457 - y2_output_root_mean_squared_error: 1.5703 - val_loss: 37.4293 - val_y1_output_loss: 15.7011 - val_y2_output_loss: 20.6308 - val_y1_output_root_mean_squared_error: 4.0313 - val_y2_output_root_mean_squared_error: 4.6019
# Epoch 116/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.7566 - y1_output_loss: 0.9822 - y2_output_loss: 2.7501 - y1_output_root_mean_squared_error: 0.9956 - y2_output_root_mean_squared_error: 1.6630 - val_loss: 3.3053 - val_y1_output_loss: 0.6828 - val_y2_output_loss: 2.6446 - val_y1_output_root_mean_squared_error: 0.8398 - val_y2_output_root_mean_squared_error: 1.6125
# Epoch 117/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.4812 - y1_output_loss: 0.5283 - y2_output_loss: 1.9456 - y1_output_root_mean_squared_error: 0.7274 - y2_output_root_mean_squared_error: 1.3972 - val_loss: 2.2316 - val_y1_output_loss: 0.6569 - val_y2_output_loss: 1.5094 - val_y1_output_root_mean_squared_error: 0.8250 - val_y2_output_root_mean_squared_error: 1.2454
# Epoch 118/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.1478 - y1_output_loss: 0.6238 - y2_output_loss: 2.5442 - y1_output_root_mean_squared_error: 0.7838 - y2_output_root_mean_squared_error: 1.5917 - val_loss: 5.4980 - val_y1_output_loss: 0.7901 - val_y2_output_loss: 4.5432 - val_y1_output_root_mean_squared_error: 0.9043 - val_y2_output_root_mean_squared_error: 2.1634
# Epoch 119/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.8264 - y1_output_loss: 0.6006 - y2_output_loss: 2.2025 - y1_output_root_mean_squared_error: 0.7782 - y2_output_root_mean_squared_error: 1.4902 - val_loss: 1.7608 - val_y1_output_loss: 0.5954 - val_y2_output_loss: 1.1319 - val_y1_output_root_mean_squared_error: 0.7810 - val_y2_output_root_mean_squared_error: 1.0728
# Epoch 120/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.7406 - y1_output_loss: 0.5622 - y2_output_loss: 2.2608 - y1_output_root_mean_squared_error: 0.7455 - y2_output_root_mean_squared_error: 1.4781 - val_loss: 10.2259 - val_y1_output_loss: 0.9284 - val_y2_output_loss: 9.0212 - val_y1_output_root_mean_squared_error: 0.9781 - val_y2_output_root_mean_squared_error: 3.0445
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.5609 - y1_output_loss: 0.1228 - y2_output_loss: 0.4343 - y1_output_root_mean_squared_error: 0.3511 - y2_output_root_mean_squared_error: 0.6616 - val_loss: 0.5703 - val_y1_output_loss: 0.1977 - val_y2_output_loss: 0.3552 - val_y1_output_root_mean_squared_error: 0.4523 - val_y2_output_root_mean_squared_error: 0.6047
# Epoch 462/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.5203 - y1_output_loss: 0.1331 - y2_output_loss: 0.3830 - y1_output_root_mean_squared_error: 0.3665 - y2_output_root_mean_squared_error: 0.6213 - val_loss: 0.6105 - val_y1_output_loss: 0.2153 - val_y2_output_loss: 0.3828 - val_y1_output_root_mean_squared_error: 0.4713 - val_y2_output_root_mean_squared_error: 0.6232
# Epoch 463/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.5070 - y1_output_loss: 0.1343 - y2_output_loss: 0.3723 - y1_output_root_mean_squared_error: 0.3649 - y2_output_root_mean_squared_error: 0.6115 - val_loss: 0.7211 - val_y1_output_loss: 0.2777 - val_y2_output_loss: 0.4337 - val_y1_output_root_mean_squared_error: 0.5335 - val_y2_output_root_mean_squared_error: 0.6606
# Epoch 464/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4630 - y1_output_loss: 0.1095 - y2_output_loss: 0.3557 - y1_output_root_mean_squared_error: 0.3302 - y2_output_root_mean_squared_error: 0.5949 - val_loss: 1.2661 - val_y1_output_loss: 0.5358 - val_y2_output_loss: 0.6998 - val_y1_output_root_mean_squared_error: 0.7442 - val_y2_output_root_mean_squared_error: 0.8440
# Epoch 465/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4842 - y1_output_loss: 0.1386 - y2_output_loss: 0.3427 - y1_output_root_mean_squared_error: 0.3730 - y2_output_root_mean_squared_error: 0.5874 - val_loss: 0.7058 - val_y1_output_loss: 0.2025 - val_y2_output_loss: 0.4805 - val_y1_output_root_mean_squared_error: 0.4572 - val_y2_output_root_mean_squared_error: 0.7048
# Epoch 466/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3803 - y1_output_loss: 0.1060 - y2_output_loss: 0.2740 - y1_output_root_mean_squared_error: 0.3259 - y2_output_root_mean_squared_error: 0.5235 - val_loss: 0.6374 - val_y1_output_loss: 0.2317 - val_y2_output_loss: 0.3851 - val_y1_output_root_mean_squared_error: 0.4896 - val_y2_output_root_mean_squared_error: 0.6307
# Epoch 467/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.6178 - y1_output_loss: 0.1498 - y2_output_loss: 0.4732 - y1_output_root_mean_squared_error: 0.3870 - y2_output_root_mean_squared_error: 0.6842 - val_loss: 0.7697 - val_y1_output_loss: 0.3318 - val_y2_output_loss: 0.4175 - val_y1_output_root_mean_squared_error: 0.5836 - val_y2_output_root_mean_squared_error: 0.6550
# Epoch 468/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4107 - y1_output_loss: 0.1131 - y2_output_loss: 0.3175 - y1_output_root_mean_squared_error: 0.3358 - y2_output_root_mean_squared_error: 0.5458 - val_loss: 4.1444 - val_y1_output_loss: 0.4572 - val_y2_output_loss: 3.6669 - val_y1_output_root_mean_squared_error: 0.6821 - val_y2_output_root_mean_squared_error: 1.9181
# Epoch 469/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.7532 - y1_output_loss: 0.1789 - y2_output_loss: 0.5829 - y1_output_root_mean_squared_error: 0.4213 - y2_output_root_mean_squared_error: 0.7588 - val_loss: 1.9986 - val_y1_output_loss: 0.4769 - val_y2_output_loss: 1.5138 - val_y1_output_root_mean_squared_error: 0.6987 - val_y2_output_root_mean_squared_error: 1.2290
# Epoch 470/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4690 - y1_output_loss: 0.1221 - y2_output_loss: 0.3647 - y1_output_root_mean_squared_error: 0.3466 - y2_output_root_mean_squared_error: 0.5906 - val_loss: 2.8379 - val_y1_output_loss: 0.6955 - val_y2_output_loss: 2.0797 - val_y1_output_root_mean_squared_error: 0.8432 - val_y2_output_root_mean_squared_error: 1.4584
# Epoch 471/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.5417 - y1_output_loss: 0.1416 - y2_output_loss: 0.3974 - y1_output_root_mean_squared_error: 0.3767 - y2_output_root_mean_squared_error: 0.6323 - val_loss: 0.6775 - val_y1_output_loss: 0.2684 - val_y2_output_loss: 0.3963 - val_y1_output_root_mean_squared_error: 0.5229 - val_y2_output_root_mean_squared_error: 0.6357
# Epoch 472/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.5124 - y1_output_loss: 0.1238 - y2_output_loss: 0.3877 - y1_output_root_mean_squared_error: 0.3526 - y2_output_root_mean_squared_error: 0.6230 - val_loss: 0.8152 - val_y1_output_loss: 0.2274 - val_y2_output_loss: 0.5636 - val_y1_output_root_mean_squared_error: 0.4842 - val_y2_output_root_mean_squared_error: 0.7620
# Epoch 473/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3238 - y1_output_loss: 0.0915 - y2_output_loss: 0.2315 - y1_output_root_mean_squared_error: 0.3015 - y2_output_root_mean_squared_error: 0.4825 - val_loss: 0.9410 - val_y1_output_loss: 0.3570 - val_y2_output_loss: 0.5883 - val_y1_output_root_mean_squared_error: 0.5980 - val_y2_output_root_mean_squared_error: 0.7638
# Epoch 474/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.5615 - y1_output_loss: 0.1497 - y2_output_loss: 0.4086 - y1_output_root_mean_squared_error: 0.3866 - y2_output_root_mean_squared_error: 0.6419 - val_loss: 0.7108 - val_y1_output_loss: 0.2704 - val_y2_output_loss: 0.4229 - val_y1_output_root_mean_squared_error: 0.5271 - val_y2_output_root_mean_squared_error: 0.6580
# Epoch 475/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4317 - y1_output_loss: 0.1156 - y2_output_loss: 0.3124 - y1_output_root_mean_squared_error: 0.3416 - y2_output_root_mean_squared_error: 0.5612 - val_loss: 0.5641 - val_y1_output_loss: 0.2029 - val_y2_output_loss: 0.3457 - val_y1_output_root_mean_squared_error: 0.4577 - val_y2_output_root_mean_squared_error: 0.5955
# Epoch 476/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3860 - y1_output_loss: 0.1112 - y2_output_loss: 0.2717 - y1_output_root_mean_squared_error: 0.3349 - y2_output_root_mean_squared_error: 0.5233 - val_loss: 0.6162 - val_y1_output_loss: 0.1880 - val_y2_output_loss: 0.4087 - val_y1_output_root_mean_squared_error: 0.4400 - val_y2_output_root_mean_squared_error: 0.6501
# Epoch 477/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4086 - y1_output_loss: 0.1174 - y2_output_loss: 0.2878 - y1_output_root_mean_squared_error: 0.3441 - y2_output_root_mean_squared_error: 0.5387 - val_loss: 0.5255 - val_y1_output_loss: 0.1908 - val_y2_output_loss: 0.3225 - val_y1_output_root_mean_squared_error: 0.4437 - val_y2_output_root_mean_squared_error: 0.5733
# Epoch 478/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3879 - y1_output_loss: 0.1122 - y2_output_loss: 0.2737 - y1_output_root_mean_squared_error: 0.3362 - y2_output_root_mean_squared_error: 0.5243 - val_loss: 0.5924 - val_y1_output_loss: 0.1885 - val_y2_output_loss: 0.3852 - val_y1_output_root_mean_squared_error: 0.4403 - val_y2_output_root_mean_squared_error: 0.6313
# Epoch 479/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4073 - y1_output_loss: 0.1160 - y2_output_loss: 0.2888 - y1_output_root_mean_squared_error: 0.3412 - y2_output_root_mean_squared_error: 0.5394 - val_loss: 0.6190 - val_y1_output_loss: 0.2298 - val_y2_output_loss: 0.3763 - val_y1_output_root_mean_squared_error: 0.4867 - val_y2_output_root_mean_squared_error: 0.6182
# Epoch 480/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4662 - y1_output_loss: 0.1204 - y2_output_loss: 0.3453 - y1_output_root_mean_squared_error: 0.3476 - y2_output_root_mean_squared_error: 0.5877 - val_loss: 0.7284 - val_y1_output_loss: 0.2217 - val_y2_output_loss: 0.4825 - val_y1_output_root_mean_squared_error: 0.4780 - val_y2_output_root_mean_squared_error: 0.7071
# Epoch 481/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4240 - y1_output_loss: 0.1072 - y2_output_loss: 0.3166 - y1_output_root_mean_squared_error: 0.3286 - y2_output_root_mean_squared_error: 0.5621 - val_loss: 0.7269 - val_y1_output_loss: 0.2065 - val_y2_output_loss: 0.4980 - val_y1_output_root_mean_squared_error: 0.4618 - val_y2_output_root_mean_squared_error: 0.7167
# Epoch 482/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4446 - y1_output_loss: 0.1147 - y2_output_loss: 0.3264 - y1_output_root_mean_squared_error: 0.3399 - y2_output_root_mean_squared_error: 0.5736 - val_loss: 0.5633 - val_y1_output_loss: 0.2079 - val_y2_output_loss: 0.3439 - val_y1_output_root_mean_squared_error: 0.4632 - val_y2_output_root_mean_squared_error: 0.5905
# Epoch 483/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5416 - y1_output_loss: 0.1176 - y2_output_loss: 0.4235 - y1_output_root_mean_squared_error: 0.3431 - y2_output_root_mean_squared_error: 0.6511 - val_loss: 0.8149 - val_y1_output_loss: 0.2715 - val_y2_output_loss: 0.5170 - val_y1_output_root_mean_squared_error: 0.5298 - val_y2_output_root_mean_squared_error: 0.7309
# Epoch 484/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.5857 - y1_output_loss: 0.1516 - y2_output_loss: 0.4390 - y1_output_root_mean_squared_error: 0.3883 - y2_output_root_mean_squared_error: 0.6595 - val_loss: 1.2169 - val_y1_output_loss: 0.3477 - val_y2_output_loss: 0.8688 - val_y1_output_root_mean_squared_error: 0.5952 - val_y2_output_root_mean_squared_error: 0.9288
# Epoch 485/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.5606 - y1_output_loss: 0.1112 - y2_output_loss: 0.4455 - y1_output_root_mean_squared_error: 0.3337 - y2_output_root_mean_squared_error: 0.6703 - val_loss: 0.7744 - val_y1_output_loss: 0.2095 - val_y2_output_loss: 0.5390 - val_y1_output_root_mean_squared_error: 0.4656 - val_y2_output_root_mean_squared_error: 0.7467
# Epoch 486/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3739 - y1_output_loss: 0.1155 - y2_output_loss: 0.2559 - y1_output_root_mean_squared_error: 0.3408 - y2_output_root_mean_squared_error: 0.5077 - val_loss: 0.6246 - val_y1_output_loss: 0.2470 - val_y2_output_loss: 0.3728 - val_y1_output_root_mean_squared_error: 0.5025 - val_y2_output_root_mean_squared_error: 0.6100
# Epoch 487/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4388 - y1_output_loss: 0.1100 - y2_output_loss: 0.3330 - y1_output_root_mean_squared_error: 0.3326 - y2_output_root_mean_squared_error: 0.5729 - val_loss: 0.7359 - val_y1_output_loss: 0.2608 - val_y2_output_loss: 0.4788 - val_y1_output_root_mean_squared_error: 0.5146 - val_y2_output_root_mean_squared_error: 0.6863
# Epoch 488/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5708 - y1_output_loss: 0.1473 - y2_output_loss: 0.4193 - y1_output_root_mean_squared_error: 0.3851 - y2_output_root_mean_squared_error: 0.6500 - val_loss: 0.5175 - val_y1_output_loss: 0.1918 - val_y2_output_loss: 0.3096 - val_y1_output_root_mean_squared_error: 0.4445 - val_y2_output_root_mean_squared_error: 0.5657
# Epoch 489/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4147 - y1_output_loss: 0.1076 - y2_output_loss: 0.3073 - y1_output_root_mean_squared_error: 0.3291 - y2_output_root_mean_squared_error: 0.5535 - val_loss: 0.7729 - val_y1_output_loss: 0.2109 - val_y2_output_loss: 0.5585 - val_y1_output_root_mean_squared_error: 0.4630 - val_y2_output_root_mean_squared_error: 0.7473
# Epoch 490/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4665 - y1_output_loss: 0.1156 - y2_output_loss: 0.3530 - y1_output_root_mean_squared_error: 0.3400 - y2_output_root_mean_squared_error: 0.5924 - val_loss: 0.7320 - val_y1_output_loss: 0.2012 - val_y2_output_loss: 0.5069 - val_y1_output_root_mean_squared_error: 0.4554 - val_y2_output_root_mean_squared_error: 0.7243
# Epoch 491/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4024 - y1_output_loss: 0.1135 - y2_output_loss: 0.2874 - y1_output_root_mean_squared_error: 0.3381 - y2_output_root_mean_squared_error: 0.5367 - val_loss: 0.6287 - val_y1_output_loss: 0.2297 - val_y2_output_loss: 0.3877 - val_y1_output_root_mean_squared_error: 0.4865 - val_y2_output_root_mean_squared_error: 0.6261
# Epoch 492/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3809 - y1_output_loss: 0.1127 - y2_output_loss: 0.2673 - y1_output_root_mean_squared_error: 0.3341 - y2_output_root_mean_squared_error: 0.5189 - val_loss: 0.7223 - val_y1_output_loss: 0.2703 - val_y2_output_loss: 0.4378 - val_y1_output_root_mean_squared_error: 0.5273 - val_y2_output_root_mean_squared_error: 0.6666
# Epoch 493/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.7140 - y1_output_loss: 0.1566 - y2_output_loss: 0.5548 - y1_output_root_mean_squared_error: 0.3960 - y2_output_root_mean_squared_error: 0.7464 - val_loss: 1.2101 - val_y1_output_loss: 0.3742 - val_y2_output_loss: 0.7964 - val_y1_output_root_mean_squared_error: 0.6216 - val_y2_output_root_mean_squared_error: 0.9076
# Epoch 494/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4234 - y1_output_loss: 0.1038 - y2_output_loss: 0.3166 - y1_output_root_mean_squared_error: 0.3228 - y2_output_root_mean_squared_error: 0.5649 - val_loss: 0.7193 - val_y1_output_loss: 0.2130 - val_y2_output_loss: 0.4833 - val_y1_output_root_mean_squared_error: 0.4692 - val_y2_output_root_mean_squared_error: 0.7065
# Epoch 495/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4029 - y1_output_loss: 0.1212 - y2_output_loss: 0.2821 - y1_output_root_mean_squared_error: 0.3491 - y2_output_root_mean_squared_error: 0.5302 - val_loss: 0.5406 - val_y1_output_loss: 0.2451 - val_y2_output_loss: 0.2835 - val_y1_output_root_mean_squared_error: 0.5023 - val_y2_output_root_mean_squared_error: 0.5369
# Epoch 496/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4779 - y1_output_loss: 0.1064 - y2_output_loss: 0.3701 - y1_output_root_mean_squared_error: 0.3270 - y2_output_root_mean_squared_error: 0.6091 - val_loss: 0.7442 - val_y1_output_loss: 0.2671 - val_y2_output_loss: 0.4649 - val_y1_output_root_mean_squared_error: 0.5230 - val_y2_output_root_mean_squared_error: 0.6861
# Epoch 497/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3404 - y1_output_loss: 0.0959 - y2_output_loss: 0.2464 - y1_output_root_mean_squared_error: 0.3087 - y2_output_root_mean_squared_error: 0.4951 - val_loss: 0.8253 - val_y1_output_loss: 0.2344 - val_y2_output_loss: 0.5715 - val_y1_output_root_mean_squared_error: 0.4908 - val_y2_output_root_mean_squared_error: 0.7645
# Epoch 498/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4023 - y1_output_loss: 0.1110 - y2_output_loss: 0.2903 - y1_output_root_mean_squared_error: 0.3341 - y2_output_root_mean_squared_error: 0.5391 - val_loss: 0.9744 - val_y1_output_loss: 0.1977 - val_y2_output_loss: 0.7457 - val_y1_output_root_mean_squared_error: 0.4520 - val_y2_output_root_mean_squared_error: 0.8776
# Epoch 499/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3932 - y1_output_loss: 0.1032 - y2_output_loss: 0.2931 - y1_output_root_mean_squared_error: 0.3216 - y2_output_root_mean_squared_error: 0.5384 - val_loss: 0.8564 - val_y1_output_loss: 0.2579 - val_y2_output_loss: 0.5766 - val_y1_output_root_mean_squared_error: 0.5146 - val_y2_output_root_mean_squared_error: 0.7692
# Epoch 500/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4117 - y1_output_loss: 0.1147 - y2_output_loss: 0.2978 - y1_output_root_mean_squared_error: 0.3360 - y2_output_root_mean_squared_error: 0.5467 - val_loss: 0.6019 - val_y1_output_loss: 0.2355 - val_y2_output_loss: 0.3514 - val_y1_output_root_mean_squared_error: 0.4911 - val_y2_output_root_mean_squared_error: 0.6006

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 37us/sample - loss: 0.6019 - y1_output_loss: 0.2387 - y2_output_loss: 0.3556 - y1_output_root_mean_squared_error: 0.4911 - y2_output_root_mean_squared_error: 0.6006
# Loss = 0.6018975466102748, Y1_loss = 0.23873457312583923, Y1_mse = 0.4910723865032196, Y2_loss = 0.35559001564979553, Y2_mse = 0.6006208658218384

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
